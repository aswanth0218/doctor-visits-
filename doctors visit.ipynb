# %% [markdown]
# Import packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv("DoctorVisits-DA.csv ")

# %%
df.head(10)
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
# 5           6       1  female  0.19    0.35        5        1       9      no
# 6           7       1  female  0.19    0.55        4        0       2      no
# 7           8       1  female  0.19    0.15        3        0       6      no
# 8           9       1  female  0.19    0.65        2        0       5     yes
# 9          10       1    male  0.19    0.15        1        0       0     yes
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# ...

# %% [markdown]
# Display complete information about the columns the dataset as column name,count,datatype and overall memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# Find out the total no : of people based on their count of illness

# %%
df["illness"].value_counts()
# Out:
# illness
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: count, dtype: int64

# %% [markdown]
# Find the duplicate value

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5185    False
# 5186    False
# 5187    False
# 5188    False
# 5189    False
# Length: 5190, dtype: bool

# %% [markdown]
# Gender wise illness

# %%
df["gender"].value_counts()
# Out:
# gender
# female    2702
# male      2488
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZE AND ANALYSE MAX , MIN AND MEDIAN

# %%
y = list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# Find out the no of days of reduced activity of male and female seperatly due to illenes

# %%
df.groupby(['gender', 'reduced']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %% [markdown]
# visualize duplicate value on a heat map

# %%
sns.heatmap(df.isnull(),cbar = False,cmap='viridis')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,20))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='green')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 plt.figure(figsize=(10,20))
# ----> 2 sns.heatmap(df.corr(),cbar=True,annot=True,cmap='green')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
# ...

# %% [markdown]
# Analyse how the income of a patient affectes the no of visits to the hospital

# %%
plt.figure(figsize=(6,8))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# Count and Visualize the number of Males and Females affected by illness.

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %% [markdown]
# Visualize the Percentage of People getting Govt. health insurance due to low income, due to old age. Also calculate the Percentage of People having Private Health Insurance

# %%
#insurance due to low income
label=['yes','no']
y=df[df['freepoor']=='yes']
y=df[df['freepoor']=='no']
x = [y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to low income")
plt.show()

#people having private health insurance
label=['yes','no']
y=df[df['private']=='yes']
y=df[df['private']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people having private health insurance")
plt.show()

#people getting govt insurance due to old age, disability or veteran status
label=['yes','no']
y=df[df['freerepat']=='yes']
y=df[df['freerepat']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt insurance due to old age, disability or veteran status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 7
#       5 #x = [y.shape[0],n.shape[0]]
#       6 plt.figure(figsize=(5,5))
# ----> 7 plt.pie(x,labels=label)
#       8 plt.title("% of people getting govt health insurance due to low income")
#       9 plt.show()
#
# NameError: name 'x' is not defined

# %% [markdown]
# Plot bar chart to analyse the reduced days of activity due to illness based on Gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
#create bar chart
plt.barh(db['gender'],db['reduced'],color=['cornflowerblue','lightseagreen'])
#adding the aesthetics
plt.title('bar chart')
plt.xlabel('gender')
plt.ylabel('reduced activity')
#show the plot
plt.show()
